# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../canada_per_capita_income.csv')
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.shape
# Out:
# (47, 2)

# %%
df.tail()
# Out:
#     year  per capita income (US$)
# 42  2012              42665.25597
# 43  2013              42676.46837
# 44  2014              41039.89360
# 45  2015              35175.18898
# 46  2016              34229.19363

# %%
plt.xlabel("year")
plt.ylabel('income')
plt.scatter(x=df.year, y=df['per capita income (US$)'], color='red', marker='o')
plt.grid()
plt.show()

# %%
indep_df_year = df.drop('per capita income (US$)', axis='columns') # Year
indep_df
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
dep_df_income = pd.DataFrame(df['per capita income (US$)']) # Income
dep_df_income
# Out:
#     per capita income (US$)
# 0               3399.299037
# 1               3768.297935
# 2               4251.175484
# 3               4804.463248
# 4               5576.514583
# 5               5998.144346
# 6               7062.131392
# 7               7100.126170
# 8               7247.967035
# 9               7602.912681
# 10              8355.968120
# 11              9434.390652
# 12              9619.438377
# 13             10416.536590
# 14             10790.328720
# 15             11018.955850
# 16             11482.891530
# 17             12974.806620
# 18             15080.283450
# 19             16426.725480
# 20             16838.673200
# 21             17266.097690
# 22             16412.083090
# 23             15875.586730
# 24             15755.820270
# 25             16369.317250
# 26             16699.826680
# 27             17310.757750
# 28             16622.671870
# 29             17581.024140
# 30             18987.382410
# 31             18601.397240
# ...

# %%
# Creating linear regression line:
reg = linear_model.LinearRegression()
reg.fit(indep_df_year,dep_df_income)
# Out:
# LinearRegression()

# %%
# Creating a DataFrame for the prediction input with the same column name as the training data
prediction_input = pd.DataFrame([[2055]], columns=['year'])

# Making the prediction
predicted_income = reg.predict(prediction_input)
predicted_income
# Out:
# array([[70284.97172721]])

# %%
m = reg.coef_
m
# Out:
# array([[828.46507522]])

# %%
c = reg.intercept_
c
# Out:
# array([-1632210.75785546])

# %%
x = prediction_input
x
# Out:
#    year
# 0  2055

# %%
y = m*x + c
y
# Out:
#            year
# 0  70284.971727

# %%
# %python3 -m pip freeze
# Out:
# UsageError: Line magic function `%python3` not found (But cell magic `%%python3` exists, did you mean that instead?).
